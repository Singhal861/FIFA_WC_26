# %%
# %sql
-- Cell 2: Bronze Layer Optimization
OPTIMIZE singhal.fifa_worldcup_bronze.players ZORDER BY (player_id);
OPTIMIZE singhal.fifa_worldcup_bronze.matches ZORDER BY (match_id);
OPTIMIZE singhal.fifa_worldcup_bronze.teams ZORDER BY (team_id);
OPTIMIZE singhal.fifa_worldcup_bronze.group_standings ZORDER BY (team_id, group_name);
OPTIMIZE singhal.fifa_worldcup_bronze.knockout_bracket ZORDER BY (match_id);
OPTIMIZE singhal.fifa_worldcup_bronze.stadiums ZORDER BY (stadium_id);

# %%
# %sql
-- Cell 3: Silver Layer Optimization
OPTIMIZE singhal.fifa_worldcup_silver.silver_players ZORDER BY (player_id);
OPTIMIZE singhal.fifa_worldcup_silver.silver_player_stats_history ZORDER BY (player_id, is_current);
OPTIMIZE singhal.fifa_worldcup_silver.silver_matches ZORDER BY (match_id, stage);
OPTIMIZE singhal.fifa_worldcup_silver.silver_goal_events ZORDER BY (match_id, team_id);
OPTIMIZE singhal.fifa_worldcup_silver.silver_group_standings ZORDER BY (team_id, group_name);
OPTIMIZE singhal.fifa_worldcup_silver.silver_group_standings_history ZORDER BY (team_id, is_current);
OPTIMIZE singhal.fifa_worldcup_silver.silver_knockout_bracket ZORDER BY (match_id, round);
OPTIMIZE singhal.fifa_worldcup_silver.silver_teams ZORDER BY (team_id);
OPTIMIZE singhal.fifa_worldcup_silver.silver_stadiums ZORDER BY (stadium_id);

# %%
# %sql
-- Cell 3: Gold Layer Optimization
-- Dashboard tables optimized for fast filtering and sorting

-- Tournament bracket: filter by round, sort by match_id
OPTIMIZE singhal.fifa_worldcup_gold.gold_tournament_bracket ZORDER BY (round, match_id);

-- Match schedule: filter by datetime and status (upcoming/live/finished)
OPTIMIZE singhal.fifa_worldcup_gold.gold_match_schedule ZORDER BY (match_datetime_utc, match_status);

-- Points table: filter by group, sort by points/goal difference
OPTIMIZE singhal.fifa_worldcup_gold.gold_points_table ZORDER BY (group_name, points, goal_difference);

-- Player leaderboard: sort by goals, assists, rating
OPTIMIZE singhal.fifa_worldcup_gold.gold_player_leaderboard ZORDER BY (total_goals, player_id);

-- Golden boot race: sort by goals scored descending
OPTIMIZE singhal.fifa_worldcup_gold.gold_golden_boot_race ZORDER BY (goals_scored, player_id);

-- Team summary: filter by team_id, sort by points/wins
OPTIMIZE singhal.fifa_worldcup_gold.gold_team_summary ZORDER BY (team_id, total_points);

# %%
# %sql
-- Cell 4: Gold Layer Vacuum
-- Remove old data files (retain 7 days = 168 hours)
VACUUM singhal.fifa_worldcup_gold.gold_tournament_bracket RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_match_schedule RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_points_table RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_player_leaderboard RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_golden_boot_race RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_team_summary RETAIN 168 HOURS;

# %%
# %sql
VACUUM singhal.fifa_worldcup_gold.gold_matches RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_players RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_points_table RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_players_stats_history RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_golden_boot_race RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_team_summary RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_tournament_bracket RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_match_schedule RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_gold.gold_tournament_schedule RETAIN 168 HOURS;

# %%
# %sql
-- Cell 4: Bronze Layer Vacuum
VACUUM singhal.fifa_worldcup_bronze.players RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_bronze.matches RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_bronze.teams RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_bronze.group_standings RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_bronze.knockout_bracket RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_bronze.stadiums RETAIN 168 HOURS;

# %%
# %sql
-- Cell 5: Silver Layer Vacuum
VACUUM singhal.fifa_worldcup_silver.silver_players RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_player_stats_history RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_matches RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_goal_events RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_group_standings RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_group_standings_history RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_knockout_bracket RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_teams RETAIN 168 HOURS;
VACUUM singhal.fifa_worldcup_silver.silver_stadiums RETAIN 168 HOURS;
